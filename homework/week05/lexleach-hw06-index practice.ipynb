# %% [markdown]
# # GEOG 592 — Module 6 Homework
# ## Indexing Practice

# %% [markdown]
# ### Python Indexing Refresher

# %%
locations = ["Oak", "Pine", "Maple", "Cedar", "Elm"]

# %% [markdown]
# #### 1. What value is returned by locations[0]?
# Oak

# %%
locations[0]
# Out:
# 'Oak'

# %% [markdown]
# #### 2. What value is returned by locations[4]?
# Elm

# %%
locations[4]
# Out:
# 'Elm'

# %% [markdown]
# #### 3. What values are returned by locations[1:4]?
# Pine, Maple, Cedar

# %%
locations[1:4]
# Out:
# ['Pine', 'Maple', 'Cedar']

# %% [markdown]
# #### 4. Write an indexing expression that returns "Maple".
# locations[2]

# %%
locations[2]
# Out:
# 'Maple'

# %%
points = [[100, 200], [140, 230], [180, 260], [120, 280]]

# %% [markdown]
# #### 5. What does points[2] return?
# [180, 260]

# %%
points[2]
# Out:
# [180, 260]

# %% [markdown]
# #### 6. What does points[2][1] return? Explain what each index selects.
# 260, the first index, [2], selects the list in the second index position and the second index selects the individual value in the first index in the list.

# %%
points[2][1]
# Out:
# 260

# %% [markdown]
# #### 7. Write an expression that returns the x-coordinate of the second point. Assume the coordinates are stored as [x,y].
# points[1][0]

# %%
points[1][0]
# Out:
# 140

# %% [markdown]
# ### Pandas Indexing Refresher

# %%
import pandas as pd

df = pd.DataFrame({
    "name": ["Oak", "Pine", "Maple", "Cedar"],
    "ft": [25, 48, 31, 60],
    "zone": ["A", "B", "A", "B"]
})

# %% [markdown]
# #### 8. What type of object is returned by df["ft"]?
# Series

# %%
print(type(df["ft"]))
# Out:
# <class 'pandas.Series'>

# %% [markdown]
# #### 9. Write code to select the name and ft columns together.
# df[["name", "ft"]]

# %%
df[["name", "ft"]]
# Out:
#     name  ft
# 0    Oak  25
# 1   Pine  48
# 2  Maple  31
# 3  Cedar  60

# %% [markdown]
# #### 10. What row is returned by df.iloc[1]?
# The second row:\
# name: Pine\
# ft: 48\
# zone: B

# %%
df.iloc[1]
# Out:
# name    Pine
# ft        48
# zone       B
# Name: 1, dtype: object

# %% [markdown]
# #### 11. Write code using iloc to select the first three rows.
# df.iloc[0:3]

# %%
df.iloc[0:3]
# Out:
#     name  ft zone
# 0    Oak  25    A
# 1   Pine  48    B
# 2  Maple  31    A

# %% [markdown]
# #### 12. Write code to select rows where ft is greater than 30.
# df[df["ft"]>30]

# %%
df[df["ft"]>30]
# Out:
#     name  ft zone
# 1   Pine  48    B
# 2  Maple  31    A
# 3  Cedar  60    B

# %% [markdown]
# #### 13. What rows are returned by df.iloc[1:3]?
# The second & third row:\
# name: Pine, Maple\
# ft: 48, 31\
# zone: B, A

# %%
df.iloc[1:3]
# Out:
#     name  ft zone
# 1   Pine  48    B
# 2  Maple  31    A

# %% [markdown]
# ### Moving to NumPy Arrays

# %%
import numpy as np
points = np.array([
    [100, 200],
    [140, 230],
    [180, 260],
    [120, 280]
])

# %% [markdown]
# #### 14. What does points.shape return, and what do the two numbers mean?
# (4,2) --> 4 rows & 2 columns

# %%
points.shape
# Out:
# (4, 2)

# %% [markdown]
# #### 15. What does points[0] return?
# array([100,200])

# %%
points[0]
# Out:
# array([100, 200])

# %% [markdown]
# #### 16. What does points[0, 1] return?
# 200

# %%
points[0,1]
# Out:
# np.int64(200)

# %% [markdown]
# #### 17. What does points[:, 0] return? Explain the colon.
# array([100,140,180,120]) --> The colon indicates the selection of all rows

# %%
points[:,0]
# Out:
# array([100, 140, 180, 120])

# %% [markdown]
# #### 18. What does points[:, 1] return?
# array([200,230,260,280])

# %%
points[:,1]
# Out:
# array([200, 230, 260, 280])

# %% [markdown]
# #### 19. Write NumPy indexing code that returns the second and third rows.
# points[1:4]

# %%
points[1:4]
# Out:
# array([[140, 230],
#        [180, 260],
#        [120, 280]])

# %% [markdown]
# #### 20. Compare points[2][1] with points[2, 1].
# points[2][1] will index within a hierarchical Python list that might contain a list within a list. points[2,1] on the other hand is used for indexing within a NumPy array.

# %%
points[2][1]
points[2,1]
# Out:
# np.int64(260)

# %% [markdown]
# ### Vectorized Operations

# %%
shift = np.array([10, 20])

# %% [markdown]
# #### 21. Without running the code, determine the result of points + shift.
# ([[110,220],\
# [150,250],\
# [190,280],\
# [130,300]])

# %%
points + shift
# Out:
# array([[110, 220],
#        [150, 250],
#        [190, 280],
#        [130, 300]])

# %% [markdown]
# #### 22. Why does this operation not require a Python for loop?
# There is essentially an already store methon with NumPy to complete the loop through each set of coordinates within "points". When we store each array with NumPy we can just call on the already stored operation.

# %% [markdown]
# ### Boolean Masks and Spatial Queries

# %%
x = points[:, 0]
y = points[:, 1]

inside = (x >= 110) & (x <= 150) & (y >= 220) & (y <= 290)

# %% [markdown]
# #### 23. Write the Boolean values stored in inside[:].
# array([False, True, False, True])

# %%
inside[:]
# Out:
# array([False,  True, False,  True])

# %% [markdown]
# #### 24. What does points[inside] return?
# array([140,230],
# [120,180])

# %%
points[inside]
# Out:
# array([[140, 230],
#        [120, 280]])

# %% [markdown]
# #### 25. In GIS language, what spatial operation is this Boolean mask approximating?
# Vectorization

# %% [markdown]
# ### np.where() and Classification

# %%
elevation = np.array([240,510,430,680])
classes = np.where(elevation >= 500, 1, 0)

# %% [markdown]
# #### 26. What values are stored in classes[:]?
# array([0,1,0,1])

# %%
classes[:]
# Out:
# array([0, 1, 0, 1])

# %% [markdown]
# #### 27. In your own words, explain the three arguments in np.where(condition, value_if_true, value_if_false).
# The first argument is a condition that designates which values to select (ex. x > 3), the second argument is the value to store if the condition is true and the final argument is the value to store if the condition is not met.

# %% [markdown]
# ### Distance and Pandas Connection

# %%
a = np.array([100, 200])
b = np.array([140, 230])
distance = np.sqrt(((a - b) ** 2).sum())

# %% [markdown]
# #### 28. What does a - b return?
# array([-40, -30])

# %%
a - b
# Out:
# array([-40, -30])

# %% [markdown]
# #### 29. Explain why this calculation is an example of vectorized arithmetic.
# ```python
# distance = np.sqrt(((a - b) ** 2).sum())
# ```
# This is an example of vectorized arithmetic b/c rather than writing a loop for this equation to apply to every row, NumPy will perform the operation on the whole array.

# %%
ft_array = df["ft"].to_numpy()

# %% [markdown]
# #### 30. What type of object is ft_array?
# numpy.ndarray

# %%
type(ft_array)
# Out:
# numpy.ndarray

# %% [markdown]
# #### 31. What happened to the pandas index and column label when the Series was converted to NumPy?
# The index and column label will be removed and only the values in the "ft" list will be extracted and stored in "ft_array".

# %% [markdown]
# ### Big Picture
# #### 32. Complete the table by describing what is being selected.
# **Python list:** locations[2]\
# third value in list\
# \
# **Nested Python list:** points_list[2][1]\
# third list, second value in list\
# \
# **pandas DataFrame:** df.iloc[2,1]:\
# third row, second column\
# \
# **NumPy array:** point[2,1]\
# third point list, second value\
# \
# **NumPy array:** point[:,0]\
# all rows, first column values

# %% [markdown]
# #### 33. In one sentence: what is the main indexing idea that stays the same across Python, pandas, and NumPy?
# The main indexing idea that remained the same across Python, pandas, and NumPy is the ordering of the index starting w/ 0 and the use of a colon to indicate the selection of all items or certain values based on ordering (ex. 1:3).
# #### 34. What becomes easier when data are arranged as a 2-D NumPy array?
# Any mathematical operation that needs to be performed across the entire dataset w/ vectorized math operations.
