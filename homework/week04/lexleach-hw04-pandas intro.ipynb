# %% [markdown]
# # GEOG 592 — Module 4 Homework
# ## Cleaning CSV with Pandas

# %% [markdown]
# ## **Part 1:** Import pandas

# %%
import pandas as pd

# %% [markdown]
# ## **Part 2:** Open the clean csv

# %%
filename = "nc_hazardous_sites_clean.csv"
df = pd.read_csv(filename)

# %% [markdown]
# ## **Part 3:** Use the required methods

# %%
df.head()
df.shape
df.columns
df.dtypes
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2086 entries, 0 to 2085
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EPAID       2086 non-null   str
#  1   SITENAME    2086 non-null   str
#  2   SITEADDR    2086 non-null   str
#  3   SITECITY    2082 non-null   str
#  4   SITECOUNTY  2086 non-null   str
#  5   LATITUDE    2086 non-null   float64
#  6   LONGITUDE   2086 non-null   float64
# dtypes: float64(2), str(5)
# memory usage: 114.2 KB

# %% [markdown]
# ## **Part 4:** Use a mask to create a dataframe with less rows

# %%
mask = df["SITECOUNTY"].str.startswith("W", na=False)

df_W = df[mask]
df_W
# Out:
#              EPAID                              SITENAME  \
# 9     NONCD0003391                     WENDELL BLVD PFAS
# 11    NONCD0003393                  TRYON RD GOLF COURSE
# 37    NCD000813592              GA-PACIFIC CORP/HDWD SAW
# 65    NCD003182805             HACKNEY BROTHERS BODY CO.
# 71    NCD003186004  INTERNATIONAL PAPER/RICHMOND GRAVURE
# ...            ...                                   ...
# 2033  NONCD0003329                   VCP WAKE FOREST LLC
# 2035  NONCD0003331                        WEBBS CLEANERS
# 2045  NONCD0003343                     SIX FORKS RD PFAS
# 2076  NONCD0003373                     KAPKE ENTERPRISES
# 2083  NONCD0003380                       TOYOTA OF BOONE
#
#                             SITEADDR     SITECITY  SITECOUNTY   LATITUDE  \
# 9                   538 WENDELL BLVD      WENDELL        WAKE  35.802779
# 11                     1610 TRYON RD      RALEIGH        WAKE  35.740280
# ...

# %%
# Confirm new dataframe
df_W.shape
# Out:
# (176, 7)
