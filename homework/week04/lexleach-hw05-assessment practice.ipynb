# %% [markdown]
# # GEOG 592 — Module 5 Homework
# ## Practice for Programming Skills Check

# %% [markdown]
# #### 1. In the code below, identify the object and the method.
#         df.head()
# Object: df\
# Method: head()

# %% [markdown]
# #### 2. Is `df.shape` an attribute or a method?
# Attribute

# %% [markdown]
# #### 3. If `df.shape` returns `(75, 8)`, explain what both numbers mean.
# The object "df" has 75 row and 8 columns.

# %% [markdown]
# #### 4. What type of pandas object is usually returned by `df["Data_Value"]`?
# This returns a Series object which includes the column "Data_Value".

# %% [markdown]
# #### 5. What type of pandas object is usually returned by `df[["County", "Data_Value"]]`?
# This returns a data frame object because a list of columns is created and pulled from the existing dataframe.

# %% [markdown]
# ### parks = pd.DataFrame({"Park":["Oak","Pine","Maple","Cedar"], "Area":[12,25,18,40], "Visitors":[120,250,180,310]})
#
# #### 6. Write the expression that selects only the `Visitors` column from the `parks` data frame.
# ```python
# parks["Visitors"]
# ```

# %% [markdown]
# #### 7. Write the expression that selects only `Park` and `Visitors` from the `parks` data frame.
# ```python
# parks[["Park", "Visitors"]]
# ```

# %% [markdown]
# #### 8. What does `parks.iloc[0]` return?
# The first row associated with each column.

# %% [markdown]
# #### 9. What rows are selected by `parks.iloc[1:4]`?
# This code will select the second, third, and fourth row, or the rows associated with index 1, 2, and 3.

# %% [markdown]
# #### 10. Write one expression that selects rows 2 through 4 by position and then keeps only `Park` and `Area`.
# ```python
# parks.iloc[2:5][["Park", "Area"]]
# ```

# %% [markdown]
# #### 11. Write a Boolean filter that keeps only parks with `Area > 20`.
# ```python
# correct_area = parks["Area"] > 20
# ```

# %% [markdown]
# #### 12. What rows would remain after that filter?
# The rows indexed at 1 and 3.

# %% [markdown]
# #### 13. Create a new DataFrame named `large_parks` containing those rows and make it an independent copy.
# ```python
# large_parks = parks[correct_area].copy()
# ```

# %% [markdown]
# #### 14. Why might `.copy()` be useful after filtering?
# If we were to simply create 'large_parks' without the '.copy()', any edits or coding we do to the 'large_parks' object will also effect the original 'parks' object. Making a copy create a completely independent object that can be edited freely without changing the raw data.

# %% [markdown]
# #### 15. Write one line that changes all three column names to `Name`, `Area_ha`, and `Annual_Visitors` using `df.columns = [...]`.
# ```python
# parks.columns = ["Name", "Area_ha", "Annual_Visitors"]
# ```

# %% [markdown]
# #### 16. What problem occurs if the list assigned to `.columns` has only two names while the DataFrame has three columns?
# There will be a length error when the code is run becuase the data cannot recognize the third column to rename.

# %% [markdown]
# ### values = pd.Series(["12.5", "18.0", "missing", "22.5"])
# #### 17. Why might pandas store these values as strings rather than numbers?
# The the "" surrounding each of the numbers signals to the code that these values are strings.

# %% [markdown]
# #### 18. Write code using `pd.to_numeric(..., errors="coerce")` to convert the Series.
# ```python
# values = pd.to_numeric(values, errors="coerce")
# ```

# %% [markdown]
# #### 19. What happens to the value `"missing"` when `errors="coerce"` is used?
# The 'errors="coerce' addition will convert the "missing" into NaN rather than stopping the program. Indicates that it is a missing value and not a numeral.

# %% [markdown]
# #### 20. What does `.isna().sum()` tell you?
# This will count the number of missing values in the object. In this case, there will be 1.

# %% [markdown]
# #### 21. Explain the difference between `dropna()` and `fillna()`.
# The 'dropna()' method will remove all missing values entirely from a dataset. The 'fillna()' method, on the other hand, will replace missing values with a values of your choosing.

# %% [markdown]
# #### 22. Write code that sorts `parks` from the highest to lowest number of visitors.
# ```python
# parks.sort_values(
#     "Annual_Visitors",
#     ascending=False)
# ```

# %% [markdown]
# #### 23. Write code to calculate the mean and median of `Visitors`.
# ```python
# parks["Annual_Visitors"].mean()
# parks["Annual_Visitors"].median()
# ```

# %% [markdown]
# #### 24. In a strongly right-skewed distribution, which is usually larger: the mean or the median? Why?
# This data set will have a larger mean because a string right-skew implies there is an outlier with a much higher value than the rest of the data. This will result in a larger average, or mean, despite a lot of the other values being much lower.

# %% [markdown]
# #### 25. In a histogram, what does `bins=10` control?
# This will change the number of bins each of the values in the dataset will be sorted into. More specifically, setting the bins to 10 will result in 10 bins on the histogram that the data will fall into.

# %% [markdown]
# #### 26. What is `ax` in `ax = df["Value"].plot(kind="hist")`?
# The ax is a Matplotlib axes object that stores methods and attributes related to make plots.

# %% [markdown]
# #### 27. Write the Matplotlib commands that set a title, x-axis label, and y-axis label on `ax`.
# ```python
# ax.set_title(...)
# ax.set_xlabel(...)
# ax.set_ylabel(...)
# ```

# %% [markdown]
# #### 28. Explain the difference between equal interval and quantile classification.
# With an equal interval classification, each class covers the same numeric width meaning there will not be an equal number of observations in each class, just an equal width. If you want to ensure that each class has the number of observations, use quantile classifcation which does just that.

# %% [markdown]
# #### 29. Suppose `values = [5, 12, 3, 20]`. Write a short Python loop that prints only values greater than 10. Then write the pandas-style Boolean condition you would use if the same values were in a Series called `s`.
# ```python
# # Python loop
# for value in values:
#     if value > 10:
#         print(value)
#
# # Pandas-style Boolean condition
# s["values"] > 10
# ```
