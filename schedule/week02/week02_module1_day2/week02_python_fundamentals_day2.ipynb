# %% [markdown]
# <div style="padding: 30px; display: grid; grid-template-columns: 66% 34%; width: 100%; background: #13294B">
#
#   <div style="padding: 20px;">
#
#   <div class="geog592-title" style= "color: #81a4d9; font-size: 42px; font-weight: 800; letter-spacing: 2px;font-family: Impact, Haettenschweiler, Arial Black; margin: 0; line-height: 1;">
#       GEOG 592
#     </div>
#
#   <div class="geog592-subtitle" style= "color: #81a4d9; font-family: Arial, Helvetica, sans-serif; font-size: 21px; font-weight: 600; margin-top: 10px;">
#       GIS Programming
#     </div>
#
#   <div class="geog592-module" style= "color: #81a4d9; font-family: Arial, Helvetica, sans-serif; font-size: 16px; margin-top: 6px;">
#       Module 1 — Day 2: Python Fundamentals (lists, index, conditionals and loops)
#     </div>
#     </div>
#
# <div class="geog592-header" style= "background: #13294B;">
#
#   <img src="592_avatar_lr.png" alt="GEOG 592 icon">
#
#   <div>
# </div>

# %% [markdown]
# ## Learning Objectives
# By the end of class, you should be able to:
#
# - create and inspect lists;
# - access list items by index;
# - use `len()` and `.append()`;
# - use comparison operators;
# - combine conditions using `and` and `or`;
# - write `if` and `if/else` statements;
# - explain the role of the colon `:` in conditionals and loops;
# - use indentation correctly to define code blocks;
# - write a `for` loop;
# - combine a loop with a condition;
# - predict the output of short programs;
# - correct simple syntax and indentation errors.
#
# > These skills will also be tested in Programming Skills Check #1.

# %% [markdown]
# ## 1. Quick Review from Day 1
# Predict the output before running.

# %% [markdown]
# Prediction:\
# The distance is 3.2 km.

# %%
distance_m = 3200
distance_km = distance_m / 1000
print(f"The distance is {distance_km} km.")
# Out:
# The distance is 3.2 km.

# %% [markdown]
# ## 2. Lists
# A **list** stores multiple values in one variable.
#
# ```python
# cities = ["Chapel Hill", "Durham", "Raleigh"]
# ```

# %%
cities = ["Chapel Hill", "Durham", "Raleigh"]
print(cities)
# Out:
# ['Chapel Hill', 'Durham', 'Raleigh']

# %% [markdown]
# ### Indexing
#
# Lists are ordered, so list items can be selected by index.
#
# Python starts counting positions at **0**.
#
# | Item | Index |
# |---|---:|
# | `"Chapel Hill"` | 0 |
# | `"Durham"` | 1 |
# | `"Raleigh"` | 2 |

# %%
print(cities[0])
print(cities[1])
print(cities[2])
# Out:
# Chapel Hill
# Durham
# Raleigh

# %% [markdown]
# What will this print?
#
# ```python
# cities = ["Chapel Hill", "Durham", "Raleigh"]
# print(cities[1])
# ```

# %%
cities = ["Chapel Hill", "Durham", "Raleigh"]
print(cities[1])
# Out:
# Durham

# %% [markdown]
# ## 3. Counting and Adding List Items
# Use `len()` to count items and `.append()` to add an item.

# %%
distances = [100, 250, 600, 900]
print(len(distances))

distances.append(1200)
print(distances)
# Out:
# 4
# [100, 250, 600, 900, 1200]

# %% [markdown]
# ### Practice 1
# Given:
#
# ```python
# places = ["Library", "Union", "Stadium"]
# ```
#
# 1. Print the first item.
# 2. Print the number of items.
# 3. Add `"Planetarium"`.
# 4. Print the updated list.

# %%
places = ["Library", "Union", "Stadium"]
print(places[0])
print(len(places))
places.append("Planetarium")
print(places)
# Out:
# Library
# 3
# ['Library', 'Union', 'Stadium', 'Planetarium']

# %% [markdown]
# ## 4. Comparison and Logical Operators
#
# Conditions compare values.
#
# ### Comparison operators
#
# | Operator | Meaning |
# |---|---|
# | `>` | greater than |
# | `<` | less than |
# | `>=` | greater than or equal to |
# | `<=` | less than or equal to |
# | `==` | equal to |
# | `!=` | not equal to |
#
# A comparison evaluates to either `True` or `False`.
#
# ### Combining conditions with `and` and `or`
#
# Use **`and`** when **both conditions must be true**.
#
# ```python
# distance = 750
# distance > 500 and distance < 1000
# ```
#
# Use **`or`** when **at least one condition must be true**.
#
# ```python
# city = "Durham"
# city == "Durham" or city == "Raleigh"
# ```
#
# Remember:
#
# - `and` → all required conditions
# - `or` → at least one acceptable condition

# %%
distance = 750

print(distance > 500)
print(distance < 500)
print(distance == 750)
# Out:
# True
# False
# True

# %% [markdown]
# ### Practice with `and` and `or`
#
# Predict each result before running the cell.

# %% [markdown]
# Prediction:\
# True\
# False\
# True

# %%
distance = 750
city = "Durham"

print(distance > 500 and distance < 1000)
print(distance > 1000 or distance < 500)
print(city == "Durham" or city == "Raleigh")
# Out:
# True
# False
# True

# %% [markdown]
# ## 5. `if` Statements
#
# An `if` statement tells Python to run code **only when a condition is true**.
#
# ```python
# distance = 750
#
# if distance > 500:
#     print("Long distance")
# ```
#
# ### Don't forget the `:` !
#
# The colon separates the **condition** from the **code block** that is controlled by the condition.
#
# A colon is required after statements such as:
#
# ```python
# if condition:
# else:
# for item in collection:
# ```
#
# Without the colon, Python raises a `SyntaxError`.
#
# Incorrect:
#
# ```python
# if distance > 500
#     print("Long distance")
# ```
#
# Correct:
#
# ```python
# if distance > 500:
#     print("Long distance")
# ```
#
# ###  Indentation is important!
#
# Python uses **indentation** to define which lines belong to the same code block.
#
# ```python
# if distance > 500:
#     print("Long distance")
#
# print("Finished")
# ```
#
# Here:
#
# - `print("Long distance")` belongs to the `if` block and runs only when the condition is true.
# - `print("Finished")` is outside the block and runs every time.
#
# Unlike languages that use braces `{ }` such as r and JS, Python uses indentation as part of its syntax.
#
# You should use **4 spaces** for each indentation level (some editors and IDE will let you choose how to indent, but it is easiest to just be consistent.)
#
# Incorrect:
#
# ```python
# if distance > 500:
# print("Long distance")
# ```
#
# Correct:
#
# ```python
# if distance > 500:
#     print("Long distance")
# ```
#
# Nested blocks use additional indentation:
#
# ```python
# if distance > 500:
#     if distance < 1000:
#         print("Medium-long distance")
# ```

# %%
distance = 750

if distance > 500:
    print("Long distance")
# Out:
# Long distance

# %% [markdown]
# ### Using `and` inside an `if`
#
# Use `and` when both conditions must be satisfied.

# %%
distance = 750

if distance > 500 and distance < 1000:
    print("Distance is between 500 and 1000 meters")
# Out:
# Distance is between 500 and 1000 meters

# %% [markdown]
# ### Using `or` inside an `if`
#
# Use `or` when either condition is acceptable.

# %%
city = "Durham"

if city == "Durham" or city == "Raleigh":
    print("City is in the Triangle")
# Out:
# City is in the Triangle

# %% [markdown]
# ### Practice — Combine two conditions
#
# Complete an `if` statement so `"Selected"` prints only when `distance` is greater than `500` **and** less than `1000`.

# %%
distance = 750

# Write your condition below
if distance > 500 and distance < 1000:
    print('Selected')
# Out:
# Selected

# %% [markdown]
# ### Practice 2
# Write an `if` statement that prints `"Large area"` when `area` is greater than `5000`.

# %%
area = 7200

# Write your if statement below
if area > 5000:
    print('Large area')
# Out:
# Large area

# %% [markdown]
# ## 6. `if` / `else`
# Use `else` when you want an alternative action when the condition is false.

# %%
distance = 400

if distance > 500:
    print("Far")
else:
    print("Near")
# Out:
# Near

# %% [markdown]
# Predict the output:
#
# ```python
# population = 35000
#
# if population > 50000:
#     print("Large")
# else:
#     print("Small")
# ```

# %% [markdown]
# Prediction:\
# Small

# %%
population = 35000

if population > 50000:
    print("Large")
else:
    print("Small")
# Out:
# Small

# %% [markdown]
# ## 7. `for` Loops
# A `for` loop repeats an action for each item in a collection.
#
# Read this as: **for each city in cities, print that city.**

# %%
cities = ["Chapel Hill", "Durham", "Raleigh"]

for city in cities:
    print(city)
# Out:
# Chapel Hill
# Durham
# Raleigh

# %% [markdown]
# The previous loop should have produced three print outputs since we had three elements in the list.
# We can count how many times a loop runs by using a **counter**.
#
# A counter is a variable that we create **before** the loop. We usually start it at `0`, then increase it by `1` each time the loop runs.
#
# For example:

# %%
cities = ["Chapel Hill", "Durham", "Raleigh"]
counter = 0

for city in cities:
    counter = counter + 1
    print("Loop number:", counter)
    print("Location:", city)
# Out:
# Loop number: 1
# Location: Chapel Hill
# Loop number: 2
# Location: Durham
# Loop number: 3
# Location: Raleigh

# %% [markdown]
# Sometimes we want a loop to repeat a specific number of times.
#
# Python's `range()` function generates a sequence of numbers that we can use in a loop.
#
# For example:

# %%
n = 4

for number in range(n):

    if number == 0:
        print(number, "notice that the range started at 0")

    elif number == (n - 1):
        print(number, "notice that the range finished at", n - 1)

    else:
        print(number)
# Out:
# 0 notice that the range started at 0
# 1
# 2
# 3 notice that the range finished at 3

# %% [markdown]
# Hey notice that I used another conditional. I used `elif` , which means “else if.”
#
# It lets Python test another condition only if the previous `if` condition was false.

# %% [markdown]
# ## 8. Combining a Loop and a Condition
# This is a programming pattern that you're likely to use many times:
#
# 1. loop through a collection, then
# 2. test each value, and
# 3. execute a command *only* when the condition is true.

# %%
distances = [300, 700, 1200, 450]

for distance in distances:
    if distance > 500:
        print(distance)
# Out:
# 700
# 1200

# %% [markdown]
# Expected output:
#
# ```text
# 700
# 1200
# ```

# %% [markdown]
# ## 9. Find the Errors
# This code is supposed to print `"Large city"`:
#
# ```python
# population = 75000
#
# if population > 50000
# print("Large city")
# ```
#
# There are two important problems. Rewrite it correctly below.

# %%
# Correct the code here
population = 75000

if population > 50000:
    print("Large city")
# Out:
# Large city

# %% [markdown]
# ## 10. Integrated In-Class Practice
# Use the following data:

# %%
locations = ["Davis Library", "Student Union", "Kenan Stadium", "Morehead Planetarium"]
distances = [250, 800, 1400, 450]

# %% [markdown]
# Complete these tasks:
#
# 1. Print the second location.
# 2. Print the number of locations.
# 3. Add `"Bell Tower"` to `locations`.
# 4. Print every distance using a `for` loop.
# 5. Print only distances greater than `500`.
# 6. Change the threshold to `1000` and observe the result.

# %%
# Print the second location.
print(locations[1])

# Print the number of locations.
print(len(locations))

# Add `"Bell Tower"` to `locations`.
locations.append('Bell Tower')

# Print every distance using a `for` loop.
for distance in distances:
    print(distance)

# Print only distances greater than `500`.
for distance in distances:
    if distance > 500:
        print(distance)

#Change the threshold to `1000` and observe the result.
for distance in distances:
    if distance > 1000:
        print(distance)
# Out:
# Student Union
# 4
# 250
# 800
# 1400
# 450
# 800
# 1400
# 1400

# %%
words = ['first', 'second', 'third']
cities = ['A', 'B', 'C']

for city in cities:
    if city == 'B':
        print('B is in the ', words[n], 'element.')
    n = n + 1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3
#       4 for city in cities:
#       5     if city == 'B':
#       6         print('B is in the ', words[n], 'element.')
# ----> 7     n = n + 1
#
# NameError: name 'n' is not defined

# %% [markdown]
# ## 11. Assessment Practice
#
# ### A. Predict the output
# ```python
# values = [10, 20, 30]
#
# for value in values:
#     print(value * 2)
# ```

# %% [markdown]
# Prediction:\
# 20, 40, 60

# %% [markdown]
# ### B. Predict the output
# ```python
# distance = 400
#
# if distance > 500:
#     print("Far")
# else:
#     print("Near")
# ```

# %% [markdown]
# Prediction:\
# Near

# %% [markdown]
# ### C. Write code
# Given:
# ```python
# distances = [200, 750, 400, 1200]
# ```
# Print only values greater than `500`.

# %%
distances = [200, 750, 400, 1200]

for distance in distances:
    if distance > 500:
        print(distance)
# Out:
# 750
# 1200

# %% [markdown]
# ### D. Correct the errors
# ```python
# distance = 800
#
# if distance > 500
# print("Long")
# ```

# %%
distance = 800

if distance > 500:
    print("Long")
# Out:
# Long

# %% [markdown]
# ### E. `and`
# Predict the result:
#
# ```python
# distance = 750
# print(distance > 500 and distance < 1000)
# ```

# %% [markdown]
# Prediction:\
# True

# %%
distance = 750
print(distance > 500 and distance < 1000)
# Out:
# True

# %% [markdown]
# ### F. `or`
# Predict the result:
#
# ```python
# city = "Durham"
# print(city == "Durham" or city == "Raleigh")
# ```

# %% [markdown]
# Prediction:\
# True

# %% [markdown]
# ### G. Write a combined condition
# Write an `if` statement that prints `"Selected"` when `value` is greater than `10` **and** less than `20`.

# %%
value = 15

if value > 10 and value < 20:
    print("Selected")
# Out:
# Selected

# %% [markdown]
# ## Complete these before Programming Skills Check #1.
#
# ### Practice 1 — Lists
# ```python
# counties = ["Orange", "Durham", "Wake"]
# ```
# Print the second element in the list ("Durham"), *using the list*, then print the number of counties, and then add `"Chatham"` to the list.

# %%
counties = ["Orange", "Durham", "Wake"]

print(counties[1])
print(len(counties))
counties.append("Chatham")
print(counties)
# Out:
# Durham
# 3
# ['Orange', 'Durham', 'Wake', 'Chatham']

# %% [markdown]
# ### Practice 2 — Conditional
# Store `population = 55000`.
# If `population` is greater than `50000`, print `"Above threshold"`; otherwise print `"Below threshold"`.

# %%
population = 55000

if population > 50000:
    print("Above threshold")
else: 
    print("Below threshold")
# Out:
# Above threshold

# %% [markdown]
# ### Practice 3 — Loop
# Given:
# ```python
# areas = [2500, 7800, 12500, 4200]
# ```
# Print every value, using a loop.

# %%
areas = [2500, 7800, 12500, 4200]

for area in areas:
    print(area)
# Out:
# 2500
# 7800
# 12500
# 4200

# %% [markdown]
# ### Practice 4 — Loop + condition
# Using the same list, print only values greater than `5000`.

# %%
areas = [2500, 7800, 12500, 4200]

for area in areas:
    if area > 5000:
        print(area)
# Out:
# 7800
# 12500

# %% [markdown]
# ### Practice 5 — review
# Create:
# ```python
# place = "UNC Campus"
# distance_m = 1750
# ```
# Convert to kilometers and print:
# `UNC Campus is 1.75 km away.`

# %%
place = "UNC Campus"
distance_m = 1750

distance_km = distance_m / 1000
print(f"{place} is {distance_km} km away.")
# Out:
# UNC Campus is 1.75 km away.

# %% [markdown]
# ### Practice 6 — Debugging
# Correct:
# ```python
# values = [10, 20, 30]
#
# for value in values
# print(value)
# ```

# %%
values = [10, 20, 30]

for value in values:
    print(value)
# Out:
# 10
# 20
# 30

# %% [markdown]
# ### Practice 7 — elif
# Can you think of a situation where you would use elif?

# %% [markdown]
# Yes, you use elif when you have more than two conditions within a loop. For instance, if you had a list of variables and you wanted to print low, medium, and high values, you can separate those actions with a loop and elif

# %%
values = [10, 150, 1050]

for value in values:
    if value < 100:
        print("Low")
    elif value < 1000:
        print("Medium")
    else:
        print("High")
# Out:
# Low
# Medium
# High

# %% [markdown]
# ### Practice 8 — Challenge
# Write a loop that can print what is the index of "Kenan Stadium" in the list locations
# ```python
# locations = ["Davis Library", "Student Union", "Kenan Stadium", "Morehead Planetarium"]
# ```

# %%
locations = ["Davis Library", "Student Union", "Kenan Stadium", "Morehead Planetarium"]
counter = 0

for location in locations:
    counter = counter + 1 
    if location == "Kenan Stadium":
        print(f"{location}: {counter}")
# Out:
# Kenan Stadium: 3

# %% [markdown]
# ## Module 1 Summary
# You should now be able to work with:
#
# - variables;
# - basic data types;
# - arithmetic;
# - strings and f-strings;
# - lists and indexing;
# - `len()` and `.append()`;
# - comparison operators;
# - logical operators `and` and `or`;
# - the colon `:` that begins a code block;
# - indentation that defines which statements belong to that block;
# - `if` , `else` and `elif`;
# - `for` loops;
# - `range()`
# - counter
# - loops combined with conditions;
# - basic debugging;
# - output prediction.
#
# These are some of the concepts that will be covered by **Programming Skills Check #1**.
